# %% [markdown]
# # Initialize things

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import geopandas as gpd
import importlib as imp
import fastparquet
import pyarrow

from Transit_Quality_Study import transit_quality_study
from Transit_Quality_Study.transit_quality_study.config import *

imp.reload(transit_quality_study.config)

import Transit_Quality_Study.transit_quality_study.custom_funcs as tqs
from gtfs_functions import Feed
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Create feed
# busiest_date must be false, time_windows to group them by the whole day
feed = Feed(gtfs_feed_path, busiest_date = False, time_windows=[0, 24])

# Create GTFS df files
gtfs = tqs.Gtfs(feed)
# Out:
# INFO:root:Reading "routes.txt".
# INFO:root:accessing trips
# INFO:root:Start date is None. You should either specify a start date or set busiest_date to True.
# INFO:root:Reading "trips.txt".
# INFO:root:Reading "stop_times.txt".
# INFO:root:_trips is defined in stop_times
# INFO:root:Reading "stops.txt".
# INFO:root:computing patterns
# INFO:root:Reading "shapes.txt".

# %%
# Create combined census
census_data = pd.read_csv(census_data_path)
census_map = gpd.read_file(census_map_path)

census = tqs.merge_census(census_data, census_map)

# %% [markdown]
# # In what DA is this stop?

# %%
# Drop unnecessary columns
stop_location = gtfs.stops.drop(
    ['stop_id', 'stop_name', 'stop_url', 'wheelchair_boarding'],
    axis=1,
    inplace=False)

# Using spatial join
stop_location = gpd.sjoin(stop_location, census, how='left', predicate='within')

# Some stations have multiple instances.
stop_location = stop_location.drop_duplicates(['stop_code'], keep='first')

# Set index
stop_location.set_index('stop_code', inplace=True)
stop_location
# Out:
#             stop_lat   stop_lon  location_type parent_station  \
# stop_code
# 10118      45.446466 -73.603118              1            NaN
# 10120      45.451158 -73.593242              1            NaN
# 10122      45.457010 -73.581691              1            NaN
# 10124      45.459441 -73.572021              1            NaN
# 10126      45.461894 -73.567074              1            NaN
# ...              ...        ...            ...            ...
# 60987      45.433289 -73.907005              0            NaN
# 61121      45.411347 -73.949240              0            NaN
# 61253      45.403753 -73.940191              0            NaN
# 61274      45.610343 -73.662089              0            NaN
# 58596      45.462695 -73.898241              0            NaN
#
#                              geometry          id       a   t   dw   hh   pop  \
# stop_code
# 10118      POINT (-73.60312 45.44647)  24663382.0  0.9907  DA    0    0     0
# 10120      POINT (-73.59324 45.45116)  24661003.0  0.0526  DA  276  258   564
# 10122      POINT (-73.58169 45.45701)  24661023.0  0.0772  DA  256  244   474
# 10124      POINT (-73.57202 45.45944)  24661179.0   0.067  DA  572  551  1003
# 10126      POINT (-73.56707 45.46189)  24661222.0  0.1247  DA  648  619  1066
# ...                               ...         ...     ...  ..  ...  ...   ...
# 60987        POINT (-73.907 45.43329)  24663118.0  9.2531  DA  438  393  1095
# 61121      POINT (-73.94924 45.41135)  24663119.0  0.2103  DA    7    6   365
# 61253      POINT (-73.94019 45.40375)  24663118.0  9.2531  DA  438  393  1095
# 61274      POINT (-73.66209 45.61034)  24650240.0   0.625  DA  253  245   510
# 58596       POINT (-73.89824 45.4627)  24663077.0  3.3619  DA  367  350  1015
#
#           Type  Area (sq km)  Population   Dwellings   Households   \
# stop_code
# 10118       DA        0.9907          0.0         0.0          0.0
# 10120       DA        0.0526        564.0       276.0        258.0
# 10122       DA        0.0772        474.0       256.0        244.0
# 10124       DA        0.0670       1003.0       572.0        551.0
# 10126       DA        0.1247       1066.0       648.0        619.0
# ...        ...           ...          ...         ...          ...
# 60987       DA        9.2531       1095.0       438.0        393.0
# 61121       DA        0.2103        365.0         7.0          6.0
# 61253       DA        9.2531       1095.0       438.0        393.0
# 61274       DA        0.6250        510.0       253.0        245.0
# 58596       DA        3.3619       1015.0       367.0        350.0
#
#            v_CA21_6: Population density per square kilometre  \
# stop_code
# 10118                                                    0.0
# 10120                                                10722.4
# 10122                                                 6139.9
# 10124                                                14970.1
# 10126                                                 8548.5
# ...                                                      ...
# 60987                                                  118.3
# 61121                                                 1735.6
# 61253                                                  118.3
# 61274                                                  816.0
# 58596                                                  301.9
#
#            v_CA21_906: Median total income of household in 2020 ($)
# stop_code
# 10118                                                    NaN
# 10120                                                65000.0
# 10122                                                54800.0
# 10124                                                64000.0
# 10126                                                70000.0
# ...                                                      ...
# 60987                                               149000.0
# 61121                                                    NaN
# 61253                                               149000.0
# 61274                                                56000.0
# 58596                                                82000.0
#
# [8791 rows x 18 columns]

# %% [markdown]
# # What routes serve this stop?
# We will use stop_times, where every row indicates a bus or train stopping at a certain stop at a certain time. Obviously, we don't need to know every time the bus stops at a stop, so we will drop the multiple instances of the same line and stop, and group the routes into lists.

# %% [markdown]
# # Group stop_routes

# %%
# Drop stop_times where stop_code and route_id duplicate
stop_routes = gtfs.stop_times.drop_duplicates(['stop_code', 'route_id'], keep='first')
stop_routes = stop_routes.groupby(['stop_code', 'stop_name', 'stop_url', ]).agg(list)

# Drop the fluff
stop_routes.drop(
    ['arrival_time', 'trip_id', 'service_id', 'direction_id', 'shape_id', 'wheelchair_boarding', 'stop_id', 'stop_sequence', 'departure_time', 'geometry', 'stop_lat', 'stop_lon', 'location_type'],
    axis=1,
    inplace=True)

stop_routes
# Out:
#                                                                                                                     route_id  \
# stop_code stop_name                            stop_url
# 10118     Station Angrignon                    http://www.stm.info/fr/infos/reseaux/metro/angr...                        [1]
# 10120     Station Monk                         http://www.stm.info/fr/infos/reseaux/metro/monk                           [1]
# 10122     Station Jolicoeur                    http://www.stm.info/fr/infos/reseaux/metro/joli...                        [1]
# 10124     Station Verdun                       http://www.stm.info/fr/infos/reseaux/metro/verdun                         [1]
# 10126     Station De l'Église                  http://www.stm.info/fr/infos/reseaux/metro/de-l...                        [1]
# ...                                                                                                                      ...
# 62373     Henri-Bourassa / de l'Esplanade      https://www.stm.info/fr/recherche#stq=62373              [380, 171, 164, 135]
# 62374     Henri-Bourassa / du Bois-de-Boulogne https://www.stm.info/fr/recherche#stq=62374         [380, 171, 164, 135, 180]
# 62375     Saint-Laurent / Lighthall            https://www.stm.info/fr/recherche#stq=62375                              [69]
# 62376     Hickmore / Mega                      https://www.stm.info/fr/recherche#stq=62376                             [100]
# 62383     Transcanadienne / Tecumseh           https://www.stm.info/fr/recherche#stq=62383                             [216]
#
#                                                                                                                                           route_name  \
# stop_code stop_name                            stop_url
# 10118     Station Angrignon                    http://www.stm.info/fr/infos/reseaux/metro/angr...                                [1 Ligne 1 - Verte]
# 10120     Station Monk                         http://www.stm.info/fr/infos/reseaux/metro/monk                                   [1 Ligne 1 - Verte]
# 10122     Station Jolicoeur                    http://www.stm.info/fr/infos/reseaux/metro/joli...                                [1 Ligne 1 - Verte]
# 10124     Station Verdun                       http://www.stm.info/fr/infos/reseaux/metro/verdun                                 [1 Ligne 1 - Verte]
# 10126     Station De l'Église                  http://www.stm.info/fr/infos/reseaux/metro/de-l...                                [1 Ligne 1 - Verte]
# ...                                                                                                                                              ...
# 62373     Henri-Bourassa / de l'Esplanade      https://www.stm.info/fr/recherche#stq=62373         [380 Henri-Bourassa, 171 Henri-Bourassa, 164 D...
# 62374     Henri-Bourassa / du Bois-de-Boulogne https://www.stm.info/fr/recherche#stq=62374         [380 Henri-Bourassa, 171 Henri-Bourassa, 164 D...
# 62375     Saint-Laurent / Lighthall            https://www.stm.info/fr/recherche#stq=62375                                                [69 Gouin]
# 62376     Hickmore / Mega                      https://www.stm.info/fr/recherche#stq=62376                                            [100 Crémazie]
# 62383     Transcanadienne / Tecumseh           https://www.stm.info/fr/recherche#stq=62383                                     [216 Transcanadienne]
#
#                                                                                                               parent_station
# stop_code stop_name                            stop_url
# 10118     Station Angrignon                    http://www.stm.info/fr/infos/reseaux/metro/angr...             [STATION_M118]
# 10120     Station Monk                         http://www.stm.info/fr/infos/reseaux/metro/monk                [STATION_M120]
# 10122     Station Jolicoeur                    http://www.stm.info/fr/infos/reseaux/metro/joli...             [STATION_M122]
# 10124     Station Verdun                       http://www.stm.info/fr/infos/reseaux/metro/verdun              [STATION_M124]
# 10126     Station De l'Église                  http://www.stm.info/fr/infos/reseaux/metro/de-l...             [STATION_M126]
# ...                                                                                                                      ...
# 62373     Henri-Bourassa / de l'Esplanade      https://www.stm.info/fr/recherche#stq=62373              [nan, nan, nan, nan]
# 62374     Henri-Bourassa / du Bois-de-Boulogne https://www.stm.info/fr/recherche#stq=62374         [nan, nan, nan, nan, nan]
# 62375     Saint-Laurent / Lighthall            https://www.stm.info/fr/recherche#stq=62375                             [nan]
# 62376     Hickmore / Mega                      https://www.stm.info/fr/recherche#stq=62376                             [nan]
# 62383     Transcanadienne / Tecumseh           https://www.stm.info/fr/recherche#stq=62383                             [nan]
#
# [8791 rows x 3 columns]

# %%
stop_data = stop_routes.merge(stop_location, how='left', on=['stop_code'])
stop_data.drop(['Type', 't', 'hh', 'dw', 'a', 'pop'], axis=1, inplace=True)
stop_data
# Out:
#                             route_id  \
# stop_code
# 10118                            [1]
# 10120                            [1]
# 10122                            [1]
# 10124                            [1]
# 10126                            [1]
# ...                              ...
# 62373           [380, 171, 164, 135]
# 62374      [380, 171, 164, 135, 180]
# 62375                           [69]
# 62376                          [100]
# 62383                          [216]
#
#                                                   route_name  \
# stop_code
# 10118                                    [1 Ligne 1 - Verte]
# 10120                                    [1 Ligne 1 - Verte]
# 10122                                    [1 Ligne 1 - Verte]
# 10124                                    [1 Ligne 1 - Verte]
# 10126                                    [1 Ligne 1 - Verte]
# ...                                                      ...
# 62373      [380 Henri-Bourassa, 171 Henri-Bourassa, 164 D...
# 62374      [380 Henri-Bourassa, 171 Henri-Bourassa, 164 D...
# 62375                                             [69 Gouin]
# 62376                                         [100 Crémazie]
# 62383                                  [216 Transcanadienne]
#
#                     parent_station_x   stop_lat   stop_lon  location_type  \
# stop_code
# 10118                 [STATION_M118]  45.446466 -73.603118              1
# 10120                 [STATION_M120]  45.451158 -73.593242              1
# 10122                 [STATION_M122]  45.457010 -73.581691              1
# 10124                 [STATION_M124]  45.459441 -73.572021              1
# 10126                 [STATION_M126]  45.461894 -73.567074              1
# ...                              ...        ...        ...            ...
# 62373           [nan, nan, nan, nan]  45.547323 -73.672934              0
# 62374      [nan, nan, nan, nan, nan]  45.537554 -73.679091              0
# 62375                          [nan]  45.550630 -73.671607              0
# 62376                          [nan]  45.476435 -73.693871              0
# 62383                          [nan]  45.472044 -73.810659              0
#
#           parent_station_y                    geometry          id  \
# stop_code
# 10118                  NaN  POINT (-73.60312 45.44647)  24663382.0
# 10120                  NaN  POINT (-73.59324 45.45116)  24661003.0
# 10122                  NaN  POINT (-73.58169 45.45701)  24661023.0
# 10124                  NaN  POINT (-73.57202 45.45944)  24661179.0
# 10126                  NaN  POINT (-73.56707 45.46189)  24661222.0
# ...                    ...                         ...         ...
# 62373                  NaN  POINT (-73.67293 45.54732)  24662522.0
# 62374                  NaN  POINT (-73.67909 45.53755)  24662544.0
# 62375                  NaN  POINT (-73.67161 45.55063)  24662525.0
# 62376                  NaN  POINT (-73.69387 45.47644)  24663419.0
# 62383                  NaN  POINT (-73.81066 45.47204)  24663151.0
#
#            Area (sq km)  Population   Dwellings   Households   \
# stop_code
# 10118            0.9907          0.0         0.0          0.0
# 10120            0.0526        564.0       276.0        258.0
# 10122            0.0772        474.0       256.0        244.0
# 10124            0.0670       1003.0       572.0        551.0
# 10126            0.1247       1066.0       648.0        619.0
# ...                 ...          ...         ...          ...
# 62373            0.0712        540.0       303.0        285.0
# 62374            0.0599        656.0       300.0        288.0
# 62375            0.0952        583.0       276.0        256.0
# 62376           15.9573        467.0       203.0        194.0
# 62383            5.1553       1191.0       389.0        374.0
#
#            v_CA21_6: Population density per square kilometre  \
# stop_code
# 10118                                                    0.0
# 10120                                                10722.4
# 10122                                                 6139.9
# 10124                                                14970.1
# 10126                                                 8548.5
# ...                                                      ...
# 62373                                                 7584.3
# 62374                                                10951.6
# 62375                                                 6123.9
# 62376                                                   29.3
# 62383                                                  231.0
#
#            v_CA21_906: Median total income of household in 2020 ($)
# stop_code
# 10118                                                    NaN
# 10120                                                65000.0
# 10122                                                54800.0
# 10124                                                64000.0
# 10126                                                70000.0
# ...                                                      ...
# 62373                                                68500.0
# 62374                                                53600.0
# 62375                                                82000.0
# 62376                                                94000.0
# 62383                                               100000.0
#
# [8791 rows x 15 columns]

# %%
stop_data = gpd.GeoDataFrame(stop_data, geometry=stop_data.geometry)
stop_data.to_parquet(stop_data_path)

# %%
gtfs.to_parquet()

# %%
gtfs.has_parquet()
# Out:
# True
